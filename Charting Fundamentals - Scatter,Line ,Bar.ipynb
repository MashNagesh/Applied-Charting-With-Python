# %%
# %matplotlib notebook

# %%
import matplotlib as mpl

# %%
mpl.get_backend()
# Out:
# 'module://ipykernel.pylab.backend_inline'

# %%
import matplotlib.pyplot as plt
#plt.plot?

# %%
plt.plot(3,2,'bo')

# %%
from matplotlib.backends.backend_agg import FigureCanvasAgg
from matplotlib.figure import Figure

# Create a New Figure
fig = Figure()

#Associate fig with the backend
canvas = FigureCanvasAgg(fig)

#Add a subplot
ax = fig.add_subplot(244)

#Plotting
ax.plot(1,1,'+')

canvas.print_png('test1.png')

# %%
# %%html
# <img src='test1.png' />
# Out:
# <img src='test1.png' />

# %%
plt.figure()
plt.plot(3, 2, 'o')
ax = plt.gca()
ax.axis([0,6,0,10])
# Out:
# [0, 6, 0, 10]

# %%
#Creating a Scatter Plot

import numpy as np

x = np.array([1,2,3,4,5,6])
y = x

plt.figure()
plt.scatter(x,y)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
x = np.array([1,2,3,4,5,6])
y = x
colors = ['green']*(len(x)-1)
colors.append('red')
plt.figure()
plt.scatter(x,y,s = 100,c = colors)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
zipped = zip([1,2,3,4,5],[3,4,5,6,7])

# %%
plt.figure()
# plot a data series 'Tall students' in red using the first two elements of x and y
plt.scatter(x[:2], y[:2], s=100, c='red', label='Tall students')
# plot a second data series 'Short students' in blue using the last three elements of x and y 
plt.scatter(x[2:], y[2:], s=100, c='blue', label='Short students')
plt.xlabel(" the x axis")
plt.ylabel("the y")
plt.title("trial charts")
plt.legend(loc = 4,frameon= False)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#Line Plot trials
import numpy as np
linear = np.array([1,2,3,4,5,6])
quad = linear **2

plt.Figure()
plt.plot(linear,'-o',quad,'-o')
plt.xlabel(" Index as axis ")
plt.ylabel(" Linear and Quadratic Values ")
plt.title (" Line Plot Trial ")
plt.legend([" Linear", " Quadratic"])

# %%
plt.gca().fill_between (range(len(linear)),linear,quad,facecolor ='green', alpha =0.25)

# %%
import pandas as pd
plt.figure()
observation_dates = np.arange('2017-01-01','2017-01-07',dtype='datetime64[D]')
observation_dates = list(map(pd.to_datetime,observation_dates))
print(observation_dates)
plt.plot(observation_dates,linear,'-o', observation_dates,quad,'-o')
plt.legend(["linear","Quad"])
# Out:
# <img src="data:image/png;base64,..." width="640">
# [Timestamp('2017-01-01 00:00:00'), Timestamp('2017-01-02 00:00:00'), Timestamp('2017-01-03 00:00:00'), Timestamp('2017-01-04 00:00:00'), Timestamp('2017-01-05 00:00:00'), Timestamp('2017-01-06 00:00:00')]

# %%
x = plt.gca().xaxis

# %%
for items in x.get_ticklabels():
    items.set_rotation(45)

# %%
plt.subplots_adjust(bottom =0.25)

# %%
#Bar Charts
plt.figure()
xvals = range(len(linear))
plt.bar(xvals,quad,width=0.3,color='teal')
# Out:
# <img src="data:image/png;base64,..." width="640">
# <Container object of 6 artists>

# %%
xvals
# Out:
# range(0, 6)

# %%
new_xvals = []
for i in xvals:
    new_xvals.append(i-0.3)
plt.bar(new_xvals,linear,color='cyan',width = 0.3)
# Out:
# <Container object of 6 artists>

# %%
#Stacked bar
plt.figure()
plt.bar(xvals,linear,color='blue',width = 0.3)
plt.bar(xvals,quad,color ='olive',width = 0.3,bottom=linear)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <Container object of 6 artists>

# %%
#Creating horizontal bar graphs
plt.figure()
plt.barh(xvals,linear,height =0.5,color ='maroon')
plt.barh(xvals,quad,height =0.5,left = linear,color='brown')
# Out:
# <img src="data:image/png;base64,..." width="640">
# <Container object of 6 artists>

# %%
for spine in plt.gca().spines.values():
    spine.set_visible(False)

# %%
plt.bar.set_color('blue')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-53-b267e988c438> in <module>()
# ----> 1 plt.bar.set_color('blue')
#
# AttributeError: 'function' object has no attribute 'set_color'
